# %%
import pandas as pd
import plotly.express as px

car_data = pd.read_csv('../vehicles.csv')
fig = px.histogram(car_data, x="odometer") # criar um histograma
fig.show() # exibindo
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 6
#       4 car_data = pd.read_csv('../vehicles.csv')
#       5 fig = px.histogram(car_data, x="odometer") # criar um histograma
# ----> 6 fig.show() # exibindo
#
# File c:\Users\pgf19\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File c:\Users\pgf19\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
# ...

# %%
import os
print("Diretório atual:", os.getcwd())
print("Arquivos no diretório atual:", os.listdir('.'))
print("Arquivos no diretório pai:", os.listdir('..'))
# Out:
# Diretório atual: c:\Users\pgf19\OneDrive\Documents\VS\Repositories\sprint5_projecto\notebooks
# Arquivos no diretório atual: ['EDA.ipynb']
# Arquivos no diretório pai: ['.git', '.gitignore', 'notebooks', 'README.md', 'requirements.txt', 'vehicles.csv']
